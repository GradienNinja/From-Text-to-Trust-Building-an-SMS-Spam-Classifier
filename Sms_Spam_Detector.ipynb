# %% [markdown]
# <a href="https://colab.research.google.com/github/GradienNinja/From-Text-to-Trust-Building-an-SMS-Spam-Classifier/blob/main/Sms_Spam_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv('spam.csv', encoding='latin1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df = df[['v1', 'v2']]

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns = ['label', 'message']

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['label'].shape
# Out:
# (5572,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
# let's convert all strings to lowercase and remove punctuation
df['label'] = df['label'].str.lower().replace(r'[^\w\s]', '', regex=True)
df['message'] = df['message'].str.lower().replace(r'[^\w\s]', '', regex=True)

# %%
df['message']
# Out:
# 0       go until jurong point crazy available only in ...
# 1                                 ok lar joking wif u oni
# 2       free entry in 2 a wkly comp to win fa cup fina...
# 3             u dun say so early hor u c already then say
# 4       nah i dont think he goes to usf he lives aroun...
#                               ...
# 5567    this is the 2nd time we have tried 2 contact u...
# 5568                 will ì_ b going to esplanade fr home
# 5569    pity  was in mood for that soany other suggest...
# 5570    the guy did some bitching but i acted like id ...
# 5571                            rofl its true to its name
# Name: message, Length: 5572, dtype: object

# %%
# now we are going to vectorize the message column
# and also going to encode the label column

# for vectorizing the text data
from sklearn.feature_extraction.text import TfidfVectorizer

#for encoding the label
from sklearn.preprocessing import LabelEncoder

# %%
vectorizer = TfidfVectorizer()
x = vectorizer.fit_transform(df['message'])

# %%
le = LabelEncoder()
y = le.fit_transform(df['label'])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model = MultinomialNB(alpha=0.5)
model.fit(x_train, y_train)
# Out:
# MultinomialNB(alpha=0.5)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9730861244019139

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1453
#            1       0.98      0.81      0.89       219
#
#     accuracy                           0.97      1672
#    macro avg       0.98      0.90      0.94      1672
# weighted avg       0.97      0.97      0.97      1672

# %%
import joblib
joblib.dump(model, "spam_model.pkl")
joblib.dump(vectorizer, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']

# %%
msg = ["Congratulations! You won a free prize"]
msg_vec = vectorizer.transform(msg)
print(model.predict(msg_vec))
# Out:
# [1]
